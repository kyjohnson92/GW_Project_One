# %%
import pandas as pd

# %%
shotlog = "shot_logs.csv"

# %%
shotlogdf = pd.read_csv(shotlog)
shotlogdf.head()
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2    ...           7.7         2
# 1       1       0:14         3.4         0    ...          28.2         3
# 2       1       0:00         NaN         3    ...          10.1         2
# 3       2      11:47        10.3         2    ...          17.2         2
# 4       2      10:34        10.9         2    ...           3.7         2
#
# ...

# %%
shotlogdf['GAME_CLOCK'] = pd.to_numeric(shotlogdf['GAME_CLOCK'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1:09"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-702c3b573f14> in <module>()
# ----> 1 shotlogdf['GAME_CLOCK'] = pd.to_numeric(shotlogdf['GAME_CLOCK'])
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# ...

# %%
import datetime
import time
x = time.strptime('11:30','%M:%S')
datetime.timedelta(hours=x.tm_hour,minutes=x.tm_min,seconds=x.tm_sec).total_seconds()
# Out:
# 690.0

# %%
shotlog4 = shotlogdf.loc[(shotlogdf["PERIOD"] == 4) & 
                         (shotlogdf["SHOT_RESULT"] == "made") &
                         (shotlogdf["GAME_CLOCK"] < )
                         
                         ,:]
shotlog4.head()
# Out:
#      GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 7   21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 11  21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 12  21400890  MAR 03, 2015 - CHA vs. LAL        H  W             1
# 18  21400859    FEB 27, 2015 - CHA @ BOS        A  L            -8
# 25  21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
#
#     SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     SHOT_DIST  \
# 7             8       4       8:00         3.4         3    ...           3.5
# 11            3       4      11:32        12.1        14    ...          14.6
# 12            4       4       8:55         4.3         2    ...           5.9
# 18            5       4      10:29        20.8         0    ...          24.2
# 25            7       4      10:13        17.1         7    ...          24.6
#
#     PTS_TYPE  SHOT_RESULT CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  \
# ...
